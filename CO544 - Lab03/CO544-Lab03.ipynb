# %% [markdown]
#  1.3 Building Decision Trees

# %% [markdown]
#  i. Importing libraries

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  ii. Dataset loading and exploratory data analysis Loading Dataset

# %%
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head() # Preview the dataset
diabetes_df.shape # Number of instances and variables
# Out:
# (768, 9)

# %% [markdown]
#  Renaming columns

# %%
col_names = ['pregnant','glucose','bp','skin','insulin','bmi','pedigree','age','label']
diabetes_df.columns = col_names # Rename column names

# %% [markdown]
#  Summary of dataset

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pregnant  768 non-null    int64
#  1   glucose   768 non-null    int64
#  2   bp        768 non-null    int64
#  3   skin      768 non-null    int64
#  4   insulin   768 non-null    int64
#  5   bmi       768 non-null    float64
#  6   pedigree  768 non-null    float64
#  7   age       768 non-null    int64
#  8   label     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# Frequency distributions of values in variables

# %%
for col in col_names:
    print(diabetes_df[col].value_counts())
# Out:
# pregnant
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 17      1
# 15      1
# Name: count, dtype: int64
# glucose
# 99     17
# 100    17
# 111    14
# 125    14
# 129    14
#        ..
# 56      1
# 169     1
# 149     1
# 65      1
# 190     1
# Name: count, Length: 136, dtype: int64
# bp
# 70     57
# 74     52
# 78     45
# 68     45
# 72     44
# 64     43
# 80     40
# 76     39
# 60     37
# 0      35
# 62     34
# 66     30
# 82     30
# 88     25
# 84     23
# 90     22
# 86     21
# 58     21
# 50     13
# 56     12
# 54     11
# 52     11
# 92      8
# 75      8
# 65      7
# 85      6
# 94      6
# 48      5
# 44      4
# 96      4
# 110     3
# 106     3
# 100     3
# 98      3
# 30      2
# 46      2
# 55      2
# 104     2
# 108     2
# 40      1
# 122     1
# 95      1
# 102     1
# 61      1
# 24      1
# 38      1
# 114     1
# Name: count, dtype: int64
# skin
# 0     227
# 32     31
# 30     27
# 27     23
# 23     22
# 18     20
# 33     20
# 28     20
# 31     19
# 39     18
# 19     18
# 29     17
# 25     16
# 40     16
# 22     16
# 37     16
# 26     16
# 41     15
# 35     15
# 36     14
# 15     14
# 17     14
# 20     13
# 24     12
# 42     11
# 13     11
# 21     10
# 46      8
# 34      8
# 12      7
# 38      7
# 16      6
# 11      6
# 45      6
# 14      6
# 43      6
# 44      5
# 10      5
# 47      4
# 48      4
# 49      3
# 50      3
# 54      2
# 8       2
# 52      2
# 7       2
# 60      1
# 51      1
# 56      1
# 63      1
# 99      1
# Name: count, dtype: int64
# insulin
# 0      374
# 105     11
# 130      9
# 140      9
# 120      8
#       ...
# 178      1
# 127      1
# 510      1
# 16       1
# 112      1
# Name: count, Length: 186, dtype: int64
# bmi
# 32.0    13
# 31.6    12
# 31.2    12
# 0.0     11
# 32.4    10
#         ..
# 49.6     1
# 24.1     1
# 41.2     1
# 49.3     1
# 46.3     1
# Name: count, Length: 248, dtype: int64
# pedigree
# 0.258    6
# 0.254    6
# 0.268    5
# 0.259    5
# 0.261    5
#         ..
# 1.182    1
# 0.222    1
# 1.057    1
# 0.766    1
# 0.393    1
# Name: count, Length: 517, dtype: int64
# age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 36    16
# 38    16
# 32    16
# 45    15
# 34    14
# 46    13
# 40    13
# 43    13
# 39    12
# 35    10
# 44     8
# 50     8
# 51     8
# 52     8
# 58     7
# 54     6
# 47     6
# 49     5
# 60     5
# 53     5
# 57     5
# 48     5
# 63     4
# 66     4
# 55     4
# 62     4
# 59     3
# 56     3
# 65     3
# 67     3
# 61     2
# 69     2
# 72     1
# 81     1
# 64     1
# 70     1
# 68     1
# Name: count, dtype: int64
# label
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
#  Exploring target variable

# %%
diabetes_df['label'].value_counts()
# Out:
# label
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
#  Checking missing values in variables

# %%
diabetes_df.isnull().sum()
# Out:
# pregnant    0
# glucose     0
# bp          0
# skin        0
# insulin     0
# bmi         0
# pedigree    0
# age         0
# label       0
# dtype: int64

# %% [markdown]
# iii. Defining feature vector and target variable

# %%
X = diabetes_df.drop(['label'], axis=1)
y = diabetes_df['label']

# %% [markdown]
#  iv. Splitting data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,random_state=1) # 75% training and 25% test
X_train.shape, X_test.shape # Shapes of X_train and X_test
# Out:
# ((576, 8), (192, 8))

# %% [markdown]
#  v. Feature engineering: encoding categorical variables

# %%
X_train.dtypes # Check data types in X_train

import category_encoders as ce

encoder = ce.OrdinalEncoder(cols=X.columns.tolist())
X_train = encoder.fit_transform(X_train)
X_test = encoder.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 3
#       1 X_train.dtypes # Check data types in X_train
# ----> 3 import category_encoders as ce
#       5 encoder = ce.OrdinalEncoder(cols=X.columns.tolist())
#       6 X_train = encoder.fit_transform(X_train)
#
# File c:\Users\Sameera\AppData\Local\Programs\Python\Python313\Lib\site-packages\category_encoders\__init__.py:14
#      12 from category_encoders.cat_boost import CatBoostEncoder
#      13 from category_encoders.count import CountEncoder
# ---> 14 from category_encoders.glmm import GLMMEncoder
#      15 from category_encoders.gray import GrayEncoder
#      16 from category_encoders.hashing import HashingEncoder
#
# File c:\Users\Sameera\AppData\Local\Programs\Python\Python313\Lib\site-packages\category_encoders\glmm.py:8
#       6 import numpy as np
#       7 import pandas as pd
# ----> 8 import statsmodels.formula.api as smf
#       9 from sklearn.utils.random import check_random_state
#      10 from statsmodels.genmod.bayes_mixed_glm import BinomialBayesMixedGLM
#
# File c:\Users\Sameera\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\formula\api.py:2
#       1 import statsmodels.regression.linear_model as lm_
# ----> 2 import statsmodels.discrete.discrete_model as dm_
#       3 import statsmodels.discrete.conditional_models as dcm_
#       4 import statsmodels.regression.mixed_linear_model as mlm_
#
# File c:\Users\Sameera\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\discrete\discrete_model.py:38
#      36 import statsmodels.base._parameter_inference as pinfer
#      37 from statsmodels.base import _prediction_inference as pred
# ---> 38 from statsmodels.distributions import genpoisson_p
#      39 import statsmodels.regression.linear_model as lm
#      40 from statsmodels.tools import data as data_tools, tools
#
# File c:\Users\Sameera\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\distributions\__init__.py:7
#       2 from .empirical_distribution import (
#       3     ECDF, ECDFDiscrete, monotone_fn_inverter, StepFunction
#       4     )
#       5 from .edgeworth import ExpandedNormal
# ----> 7 from .discrete import (
#       8     genpoisson_p, zipoisson, zigenpoisson, zinegbin,
#       9     )
#      11 __all__ = [
#      12     'ECDF',
#      13     'ECDFDiscrete',
#    (...)     21     'zipoisson'
#      22     ]
#      24 test = PytestTester()
#
# File c:\Users\Sameera\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\distributions\discrete.py:5
#       3 from scipy.stats import rv_discrete, poisson, nbinom
#       4 from scipy.special import gammaln
# ----> 5 from scipy._lib._util import _lazywhere
#       7 from statsmodels.base.model import GenericLikelihoodModel
#      10 class genpoisson_p_gen(rv_discrete):
#
# ImportError: cannot import name '_lazywhere' from 'scipy._lib._util' (c:\Users\Sameera\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\_lib\_util.py)

# %% [markdown]
#  vi. Building decision tree classifier with the Gini index criterion

# %%
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=4, random_state=0)
clf_gini.fit(X_train, y_train) # Train the classifier
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=0)
